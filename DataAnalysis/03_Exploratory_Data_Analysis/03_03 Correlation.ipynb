# %% [markdown]
# # Correlation

# %%
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
path = "./Datasets/clean_df.csv"
df = pd.read_csv(path)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('S3KPG_O7IDY', width=800, height=500 )

# %% [markdown]
# <b>
#     <font size="+1">
#         <p style="color:#4496C4;">
#             Qué es correlación?
#         </p>
#     </font>
# </b>

# %% [markdown]
# La correlación sirve para medir hasta qué punto la diferentes variables son indepenientes.

# %% [markdown]
# Cuando miramos dos variables a lo largo del tiempo, si una variable cambia ¿Cómo afecta esto al cambio en otra variable?

# %% [markdown]
# Lung cancer -> Smoking

# %% [markdown]
# Rain -> Umbrella

# %% [markdown]
# <b>
#     <font size="+0">
#         <p style="color:#EB7969;">
#             Correlation does Not imply Causation
#         </p>
#     </font>
# </b>

# %% [markdown]
# <b>
#     <font size="+1">
#         <p style="color:#90B736;">
#             Positive linear relationship
#         </p>
#     </font>
# </b>

# %%
import seaborn as sns

# %%
sns.regplot(x = "engine-size", y = "price", data = df)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %% [markdown]
# <b>
#     <font size="+1">
#         <p style="color:#90B736;">
#             Negative linear relationship
#         </p>
#     </font>
# </b>

# %%
sns.regplot(x = "highway-mpg", y = "price", data = df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %% [markdown]
# <b>
#     <font size="+1">
#         <p style="color:#BB8FCE;">
#             Week correlation
#         </p>
#     </font>
# </b>

# %%
sns.regplot(x = "peak-rpm", y = "price", data = df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>
